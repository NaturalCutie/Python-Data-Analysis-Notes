# %% [markdown]
# # **3.23_read_csv**

# %% [markdown]
# ###  一、读取CSV

# %% [markdown]
# 1. 导入Pandas
#
#    `import pandas as pd`
#
# 2. read_csv函数
#
#    顾名思义是用来读CSV文件的
#
#    把文件的路径作为参数
#
#    **以下用代码而不是软件去处理数据，能更快处理完成**

# %%
import pandas as pd
df1 = pd.read_csv('3.23_fifa_players.csv')
# 3.23_fifa_players.csv文件，里面记录了16万条国际足联球员的信息，文件体积是91MB左右
# Out:
# C:\Users\stube\AppData\Local\Temp\ipykernel_101028\4064771607.py:2: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('3.23_fifa_players.csv')

# %%
df1.head()
# Out:
#    player_id                                        player_url  fifa_version  \
# 0     158023                /player/158023/lionel-messi/150002            15
# 1      20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 2       9014                  /player/9014/arjen-robben/150002            15
# 3      41236           /player/41236/zlatan-ibrahimovic/150002            15
# 4     167495                /player/167495/manuel-neuer/150002            15
#
#    fifa_update fifa_update_date         short_name  \
# 0            2       2014-09-18           L. Messi
# 1            2       2014-09-18  Cristiano Ronaldo
# 2            2       2014-09-18          A. Robben
# 3            2       2014-09-18     Z. Ibrahimović
# 4            2       2014-09-18           M. Neuer
#
#                              long_name player_positions  overall  potential  \
# 0       Lionel Andrés Messi Cuccittini               CF       93         95
# ...

# %% [markdown]
#    1)可选参数header
#
#      a.csv文件有表头
#
#        省略可选参数header，默认会把第一行内容作为列名
#
#      b.csv文件无表头
#
#        设置'header=None',表示不要把第一行当做列名。那解析出来的DataFrame就会把第一行视为第一条数据，列名用从0开始的数据代替

# %%
df = pd.read_csv('3.23_fifa_players (no header).csv', header=None)
df.head()
# Out:
# C:\Users\stube\AppData\Local\Temp\ipykernel_101028\3507463100.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('3.23_fifa_players (no header).csv', header=None)
#       0                                                 1    2    3    \
# 0  158023                /player/158023/lionel-messi/150002   15    2
# 1   20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002   15    2
# 2    9014                  /player/9014/arjen-robben/150002   15    2
# 3   41236           /player/41236/zlatan-ibrahimovic/150002   15    2
# 4  167495                /player/167495/manuel-neuer/150002   15    2
#
#           4                  5                                    6    \
# 0  2014-09-18           L. Messi       Lionel Andrés Messi Cuccittini
# 1  2014-09-18  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2  2014-09-18          A. Robben                         Arjen Robben
# ...

# %% [markdown]
#    2)可选参数index_col
#
#      a.只用位置索引
#
#        省略可选参数index_col，默认用位置索引
#
#      b.把某一列作为标签索引
#
#        设置'index_col=列名/列的位置索引'，返回的DataFrame就会把列名的值作为标签索引。如下例子，可以通过标签索引'球员ID'，而不是仅通过位置索引，来提取数据了

# %%
df1 = pd.read_csv('3.23_fifa_players.csv', index_col='player_id')
df1.head()
# Out:
# C:\Users\stube\AppData\Local\Temp\ipykernel_101028\2611218267.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('3.23_fifa_players.csv', index_col='player_id')
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
#
#            fifa_update fifa_update_date         short_name  \
# player_id
# 158023               2       2014-09-18           L. Messi
# 20801                2       2014-09-18  Cristiano Ronaldo
# 9014                 2       2014-09-18          A. Robben
# ...

# %%
df1.loc[158023]
# Out:
#                                    player_url  fifa_version  fifa_update  \
# player_id
# 158023     /player/158023/lionel-messi/150002            15            2
# 158023     /player/158023/lionel-messi/160002            16            2
# 158023     /player/158023/lionel-messi/170002            17            2
# 158023     /player/158023/lionel-messi/180002            18            2
# 158023     /player/158023/lionel-messi/190002            19            2
# 158023     /player/158023/lionel-messi/200002            20            2
# 158023     /player/158023/lionel-messi/210002            21            2
# 158023     /player/158023/lionel-messi/220002            22            2
# 158023     /player/158023/lionel-messi/230002            23            2
#
#           fifa_update_date short_name                       long_name  \
# player_id
# 158023          2014-09-18   L. Messi  Lionel Andrés Messi Cuccittini
# 158023          2015-09-21   L. Messi  Lionel Andrés Messi Cuccittini
# ...

# %% [markdown]
# ### 二、展示CSV的方法

# %% [markdown]
# #### (一)、set_option函数

# %% [markdown]
# 1. 更改展示列数上限
#
#     默认只展示20列。
#
#     当我们遇到的数据包含非常多列的时候，输入的DataFrame里，中间有些列就会被自动忽略，被用'...'表示。
#
#     假如想查看所有列，可以通过set_option函数，提升展示的列数的上限。
#
#     第一个参数传入'display.max_columns'，表示展示列数的上限。
#
#     第二个参数传入，你希望最多看到的列数

# %%
pd.set_option('display.max_columns', 150)
df1
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 269011                      /player/269011/ziye-zhao/230002            23
# 269019                      /player/269019/junjie-wu/230002            23
# 271093                  /player/271093/kailin-barlow/230002            23
# 271555                  /player/271555/gideon-tetteh/230002            23
# 271608              /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %% [markdown]
# 2. 更改展示值的字符上限
#
#    默认的字符上限是50
#
#    当我们遇到值很长的时候，文字不会展示全，如上例子里，'player_tags'和'player_traits'两列
#
#     假如想让值展示的长度更大一些，可以通过set_option函数，提升值展示的字符上限。
#
#     第一个参数传入'display.max_colwidths'，每列里的值最多包含几个字符限。
#
#     第二个字符上限到的列数

# %%
pd.set_option('display.max_colwidth', 500)
df1
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 269011                      /player/269011/ziye-zhao/230002            23
# 269019                      /player/269019/junjie-wu/230002            23
# 271093                  /player/271093/kailin-barlow/230002            23
# 271555                  /player/271555/gideon-tetteh/230002            23
# 271608              /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %% [markdown]
# #### (二)、head/tail/sample方法

# %% [markdown]
# 可以得到开头/结尾/随机的N行

# %%
df1.head()
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
#
#            fifa_update fifa_update_date         short_name  \
# player_id
# 158023               2       2014-09-18           L. Messi
# 20801                2       2014-09-18  Cristiano Ronaldo
# 9014                 2       2014-09-18          A. Robben
# 41236                2       2014-09-18     Z. Ibrahimović
# 167495               2       2014-09-18           M. Neuer
#
#                                      long_name player_positions  overall  \
# player_id
# ...

# %%
df1.tail()
# Out:
#                                         player_url  fifa_version  fifa_update  \
# player_id
# 269011             /player/269011/ziye-zhao/230002            23            2
# 269019             /player/269019/junjie-wu/230002            23            2
# 271093         /player/271093/kailin-barlow/230002            23            2
# 271555         /player/271555/gideon-tetteh/230002            23            2
# 271608     /player/271608/aqeel-al-dhafeeri/230002            23            2
#
#           fifa_update_date      short_name          long_name  \
# player_id
# 269011          2022-09-26       Zhao Ziye                赵梓业
# 269019          2022-09-26       Wu Junjie                吴俊杰
# 271093          2022-09-26       K. Barlow      Kailin Barlow
# 271555          2022-09-26       G. Tetteh      Gideon Tetteh
# 271608          2022-09-26  A. Al Dhafeeri  Aqeel Al Dhafeeri
#
#           player_positions  overall  potential  value_eur  wage_eur  age  \
# player_id
# ...

# %%
df1.sample()
# Out:
#                                       player_url  fifa_version  fifa_update  \
# player_id
# 230762     /player/230762/saeed-al-hamsal/230002            23            2
#
#           fifa_update_date    short_name        long_name player_positions  \
# player_id
# 230762          2022-09-26  S. Al Hamsal  Saeed Al Hamsal      RB, RWB, CB
#
#            overall  potential  value_eur  wage_eur  age         dob  \
# player_id
# 230762          61         64   400000.0    2000.0   26  1996-04-18
#
#            height_cm  weight_kg  league_id league_name  league_level  \
# player_id
# 230762           172         64      350.0  Pro League           1.0
#
#            club_team_id club_name club_position  club_jersey_number  \
# player_id
# 230762         113058.0      Abha           SUB                39.0
#
#           club_loaned_from club_joined_date  club_contract_valid_until_year  \
# player_id
# 230762                 NaN       2020-09-07                          2023.0
#
# ...

# %% [markdown]
# 默认随机返回一行的数据

# %% [markdown]
# #### (三)、info方法

# %% [markdown]
# 快速了解一个DataFrame，除了看它实际的数据之外，还可以通过info,获得DataFrame的概况信息
#
# 1. 当列数太多时，只会展示部分信息

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161583 entries, 158023 to 271608
# Columns: 109 entries, player_url to player_face_url
# dtypes: float64(18), int64(44), object(47)
# memory usage: 139.6+ MB

# %% [markdown]
# 从上到下分别是：类型、索引的范围、列的数量、列的数据类型、占用memory

# %% [markdown]
# 2. 当列的数量较少时，还会返回每列具体的列名，排除掉空值后实际值的数量，和每一列的数据类型

# %%
df3 = pd.read_csv('3.23_amazon.csv')
df3.head(2)
# Out:
#    product_id  \
# 0  B07JW9H4J1
# 1  B098NS6PVG
#
#                                                                                                                                                                                         product_name  \
# 0                                 Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)
#
#                                                                             category  \
# 0  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
# 1  Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# #### (四)、descirbe方法

# %% [markdown]
# 针对数字类型的列，一次性展示多种统计信息

# %%
df1.describe()
# Out:
#         fifa_version  fifa_update        overall      potential     value_eur  \
# count  161583.000000     161583.0  161583.000000  161583.000000  1.595300e+05
# mean       19.125514          2.0      65.699071      70.744008  2.326770e+06
# std         2.559318          0.0       7.040855       6.259121  6.005746e+06
# min        15.000000          2.0      40.000000      40.000000  1.000000e+03
# 25%        17.000000          2.0      61.000000      66.000000  3.250000e+05
# 50%        19.000000          2.0      66.000000      70.000000  7.250000e+05
# 75%        21.000000          2.0      70.000000      75.000000  1.800000e+06
# max        23.000000          2.0      94.000000      95.000000  1.940000e+08
#
#             wage_eur            age      height_cm      weight_kg  \
# count  159822.000000  161583.000000  161583.000000  161583.000000
# mean    10855.409768      25.123181     181.240205      75.235031
# std     21941.656285       4.670207       6.750148       7.000456
# ...
